# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#data import

gla_df= pd.read_xlsx('C:\\Users\\GAURAVB\\Downloads\\Global Logistics Association - Data to Merge.xlsx')
gla_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 #data import
# ----> 3 gla_df= pd.read_xlsx('C:\\Users\\GAURAVB\\Downloads\\Global Logistics Association - Data to Merge.xlsx')
#       4 gla_df.head()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'

# %%
#data import

gla_df= pd.read_excel('C:\\Users\\GAURAVB\\Downloads\\Global Logistics Association - Data to Merge.xlsx')
gla_df.head()
# Out:
#                   Member ID  Last name First name               Street  \
# 0  sakaguchiabbas@email.com  Sakaguchi      Abbas           25 Dyas Rd
# 1   dorionrichard@email.com     Dorion    Richard  7101 Notre Dame St
# 2   gougeonsanjay@email.com    Gougeon     Sanjay   8580 Esplanade Ave
# 3   wrightmohamed@email.com     Wright    Mohamed        135 Dundas St
# 4     romanmarian@email.com      Roman     Marian        135 Dundas St
#
#   Apt/Ste/Unit          New Address        City State Country Zip Code  \
# 0     Ste. 101   25 Dyas RdSte. 101  North York    ON  Canada  M3B 1V7
# 1          NaN  7101 Notre Dame St     Montreal    QC  Canada  H1N 2G4
# 2          NaN   8580 Esplanade Ave    Montreal    QC  Canada  H2P 2R8
# 3          NaN        135 Dundas St   Cambridge    ON  Canada  N1R 5X1
# 4          NaN        135 Dundas St   Cambridge    ON  Canada  N1R 5X1
#
#    Dues amount  Membership end date          Member type
# ...

# %%
gla_df.tail()
# Out:
#                     Member ID   Last name First name                  Street  \
# 76     di marioross@email.com    Di Mario       Ross  35 Basswood Ave Box 21
# 77       hickeyjohn@email.com      Hickey       John           18 Forest Ave
# 78   shipleywilhelm@email.com     Shipley    Wilhelm           15 Oriole Pky
# 79  desjardinsdavid@email.com  Desjardins      David  8600 Chemin Devonshire
# 80  mcallisterbrent@email.com  McAllister      Brent       5795 Don Murie St
#
#    Apt/Ste/Unit                    New Address           City State Country  \
# 76          NaN         35 Basswood Ave Box 21    Stittsville    ON  Canada
# 77          NaN                  18 Forest Ave  Port Colborne    ON  Canada
# 78          NaN                  15 Oriole Pky         Elmira    ON  Canada
# 79      Unit 21  8600 Chemin DevonshireUnit 21     Mont-Royal    QC  Canada
# 80          NaN              5795 Don Murie St  Niagara Falls    ON  Canada
#
# ...

# %%
gla_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Member ID            81 non-null     object
#  1   Last name            81 non-null     object
#  2   First name           81 non-null     object
#  3   Street               81 non-null     object
#  4   Apt/Ste/Unit         13 non-null     object
#  5   New Address          81 non-null     object
#  6   City                 81 non-null     object
#  7   State                62 non-null     object
#  8   Country              81 non-null     object
#  9   Zip Code             65 non-null     object
#  10  Dues amount          81 non-null     int64
#  11  Membership end date  81 non-null     object
#  12  Member type          81 non-null     object
# dtypes: int64(1), object(12)
# memory usage: 8.4+ KB

# %%
gla_df.describe()
# Out:
#        Dues amount
# count    81.000000
# mean    329.246914
# std     523.311512
# min      99.000000
# 25%     149.000000
# 50%     199.000000
# 75%     199.000000
# max    2499.000000

# %%
gla_df.isna().sum()
# Out:
# Member ID               0
# Last name               0
# First name              0
# Street                  0
# Apt/Ste/Unit           68
# New Address             0
# City                    0
# State                  19
# Country                 0
# Zip Code               16
# Dues amount             0
# Membership end date     0
# Member type             0
# dtype: int64

# %%
# add new column

gla_df['Full_Name']= (gla_df['First name'] + gla_df['Last name'])

# %%
gla_df.head()
# Out:
#                   Member ID  Last name First name               Street  \
# 0  sakaguchiabbas@email.com  Sakaguchi      Abbas           25 Dyas Rd
# 1   dorionrichard@email.com     Dorion    Richard  7101 Notre Dame St
# 2   gougeonsanjay@email.com    Gougeon     Sanjay   8580 Esplanade Ave
# 3   wrightmohamed@email.com     Wright    Mohamed        135 Dundas St
# 4     romanmarian@email.com      Roman     Marian        135 Dundas St
#
#   Apt/Ste/Unit          New Address        City State Country Zip Code  \
# 0     Ste. 101   25 Dyas RdSte. 101  North York    ON  Canada  M3B 1V7
# 1          NaN  7101 Notre Dame St     Montreal    QC  Canada  H1N 2G4
# 2          NaN   8580 Esplanade Ave    Montreal    QC  Canada  H2P 2R8
# 3          NaN        135 Dundas St   Cambridge    ON  Canada  N1R 5X1
# 4          NaN        135 Dundas St   Cambridge    ON  Canada  N1R 5X1
#
#    Dues amount  Membership end date          Member type       Full_Name
# ...
